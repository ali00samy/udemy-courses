# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
udemy_course = pd.read_csv('udemy_courses_clean.csv')
udemy_course
# Out:
#       Unnamed: 0  course_id  \
# 0              0    1070968
# 1              1    1113822
# 2              2    1006314
# 3              3    1210588
# 4              4    1011058
# ...          ...        ...
# 3678        3678     775618
# 3679        3679    1088178
# 3680        3680     635248
# 3681        3681     905096
# 3682        3682     297602
#
#                                            course_title  \
# 0                    Ultimate Investment Banking Course
# 1     Complete GST Course & Certification - Grow You...
# 2     Financial Modeling for Business Analysts and C...
# 3     Beginner to Pro - Financial Analysis in Excel ...
# 4          How To Maximize Your Profits Trading Options
# ...                                                 ...
# 3678  Learn jQuery from Scratch - Master of JavaScri...
# 3679  How To Design A WordPress Website With No Codi...
# 3680                      Learn and Build using Polymer
# ...

# %%
udemy_course.isnull().sum()
# Out:
# Unnamed: 0              0
# course_id               0
# course_title            0
# url                     0
# is_paid                 0
# price                   0
# num_subscribers         0
# num_reviews             0
# num_lectures            0
# level                   0
# content_duration        0
# published_timestamp     0
# subject                 0
# clean_course_title     20
# dtype: int64

# %%
udemy_course = udemy_course.drop(columns=['Unnamed: 0'])

# %%
udemy_course.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url is_paid price  \
# 0  https://www.udemy.com/ultimate-investment-bank...    True   200
# 1      https://www.udemy.com/goods-and-services-tax/    True    75
# 2  https://www.udemy.com/financial-modeling-for-b...    True    45
# 3  https://www.udemy.com/complete-excel-finance-c...    True    95
# 4  https://www.udemy.com/how-to-maximize-your-pro...    True   200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
udemy_course['subject'].unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %%
udemy_course['subject'].value_counts()
# Out:
# subject
# Web Development        1200
# Business Finance       1199
# Musical Instruments     681
# Graphic Design          603
# Name: count, dtype: int64

# %%
udemy_course['subject'].value_counts().plot(kind='bar')
plt.xticks(rotation=45)
plt.show()

# %%
udemy_course['subject'].value_counts().plot(kind='pie')
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(udemy_course, x = 'subject')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.set_theme()

# %%
udemy_course.groupby('subject')['num_subscribers'].sum().sort_values(ascending=False)
# Out:
# subject
# Web Development        7980572
# Business Finance       1870747
# Graphic Design         1063148
# Musical Instruments     846719
# Name: num_subscribers, dtype: int64

# %%
udemy_course.groupby('subject')['num_subscribers'].mean()
# Out:
# subject
# Business Finance       1560.256047
# Graphic Design         1763.097844
# Musical Instruments    1243.346549
# Web Development        6650.476667
# Name: num_subscribers, dtype: float64

# %%
udemy_course['num_subscribers'].mean()
# Out:
# np.float64(3193.3711648112953)

# %%
udemy_course['num_subscribers'].max()
# Out:
# np.int64(268923)

# %%
udemy_course['num_subscribers'].min()
# Out:
# np.int64(0)

# %%
udemy_course['num_subscribers'].idxmax()
# Out:
# 2832

# %%
udemy_course.iloc[2832]
# Out:
# course_id                                                          41295
# course_title                        Learn HTML5 Programming From Scratch
# url                    https://www.udemy.com/learn-html5-programming-...
# is_paid                                                            False
# price                                                               Free
# num_subscribers                                                   268923
# num_reviews                                                         8629
# num_lectures                                                          45
# level                                                         All Levels
# content_duration                                              10.5 hours
# published_timestamp                                 2013-02-14T07:03:41Z
# subject                                                  Web Development
# clean_course_title                       Learn HTML5 Programming Scratch
# ...

# %%
udemy_course['level'].value_counts()
# Out:
# level
# All Levels            1932
# Beginner Level        1271
# Intermediate Level     421
# Expert Level            58
# 52                       1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,8))
data_label = udemy_course['level'].value_counts()
levelBar = sns.countplot(udemy_course, x = 'level')
levelBar.bar_label(container=levelBar.containers[0],labels= data_label)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8,8))
keys = udemy_course['level'].unique()
data = udemy_course['level'].value_counts()
plt.pie(data, labels= keys,autopct='%.0f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
udemy_course.groupby('level')['num_subscribers'].sum().sort_values(ascending=False)
# Out:
# level
# All Levels            6916112
# Beginner Level        4052843
# Intermediate Level     742005
# Expert Level            50196
# 52                         30
# Name: num_subscribers, dtype: int64

# %%
udemy_course.groupby('level')['num_subscribers'].sum().sort_values(ascending=False)
# Out:
# level
# All Levels            6916112
# Beginner Level        4052843
# Intermediate Level     742005
# Expert Level            50196
# 52                         30
# Name: num_subscribers, dtype: int64

# %%
udemy_course.groupby('subject')['level'].value_counts()
# Out:
# subject              level
# Business Finance     All Levels            699
#                      Beginner Level        341
#                      Intermediate Level    128
#                      Expert Level           31
# Graphic Design       All Levels            298
#                      Beginner Level        243
#                      Intermediate Level     57
#                      Expert Level            5
# Musical Instruments  Beginner Level        296
#                      All Levels            276
#                      Intermediate Level    101
#                      Expert Level            7
#                      52                      1
# Web Development      All Levels            659
#                      Beginner Level        391
#                      Intermediate Level    135
#                      Expert Level           15
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.barplot(udemy_course, x='level', y='num_subscribers', hue= 'subject')
plt.show()

# %%
udemy_course['price'] = udemy_course['price'].str.replace("Free|TRUE" , "0" , regex=True)

# %%
udemy_course['price'] = udemy_course['price'].astype(float)

# %%
udemy_course['price'].describe()
# Out:
# count    3683.000000
# mean       65.992398
# std        60.985586
# min         0.000000
# 25%        20.000000
# 50%        45.000000
# 75%        95.000000
# max       200.000000
# Name: price, dtype: float64

# %%
udemy_course['profit'] = udemy_course['price'] * udemy_course['num_subscribers']
udemy_course.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True  200.0
# 1      https://www.udemy.com/goods-and-services-tax/     True   75.0
# 2  https://www.udemy.com/financial-modeling-for-b...     True   45.0
# 3  https://www.udemy.com/complete-excel-finance-c...     True   95.0
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True  200.0
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
udemy_course['profit'].max()
# Out:
# np.float64(24316800.0)

# %%
udemy_course['profit'].idxmax()
# Out:
# 3235

# %%
udemy_course.iloc[3235]
# Out:
# course_id                                                         625204
# course_title                                  The Web Developer Bootcamp
# url                    https://www.udemy.com/the-web-developer-bootcamp/
# is_paid                                                             True
# price                                                              200.0
# num_subscribers                                                   121584
# num_reviews                                                        27445
# num_lectures                                                         342
# level                                                         All Levels
# content_duration                                                43 hours
# published_timestamp                                 2015-11-02T21:13:27Z
# subject                                                  Web Development
# clean_course_title                                Web Developer Bootcamp
# ...

# %%
udemy_course['is_paid'].value_counts()
# Out:
# is_paid
# True     3373
# False     310
# Name: count, dtype: int64

# %%
paid_dict = {
    'True':True ,
    'TRUE':True,
    'False':False,
    'FALSE':False,
    'https://www.udemy.com/learnguitartoworship/':True
}

# %%
udemy_course['is_paid'] = udemy_course['is_paid'].map(paid_dict)

# %%
udemy_course['is_paid'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='is_paid'>

# %%
udemy_course.groupby('is_paid')['subject'].value_counts()
# Out:
# is_paid  subject
# False    Web Development         133
#          Business Finance         96
#          Musical Instruments      46
#          Graphic Design           35
# True     Business Finance       1103
#          Web Development        1067
#          Musical Instruments     635
#          Graphic Design          568
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.barplot(udemy_course, x='is', y='num_subscribers', hue= 'subject')
plt.show()

# %%
udemy_course['published_timestamp'].str.split('T')
# Out:
# 0       [2017-01-18, 20:58:58Z]
# 1       [2017-03-09, 16:34:20Z]
# 2       [2016-12-19, 19:26:30Z]
# 3       [2017-05-30, 20:07:24Z]
# 4       [2016-12-13, 14:57:18Z]
#                  ...
# 3678    [2016-06-14, 17:36:46Z]
# 3679    [2017-03-10, 22:24:30Z]
# 3680    [2015-12-30, 16:41:42Z]
# 3681    [2016-08-11, 19:06:15Z]
# 3682    [2014-09-28, 19:51:11Z]
# Name: published_timestamp, Length: 3683, dtype: object

# %%
udemy_course['published_date'] = udemy_course['published_timestamp'].str.split('T').str.get(0)

# %%
udemy_course['published_date'] = pd.to_datetime(udemy_course['published_date'], format= '%Y-%M-%d' )

# %%
udemy_course['published_date'] = udemy_course['published_date'].str.replace('3 hours', '2017-01-18')

# %%
udemy_course.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True  200.0
# 1      https://www.udemy.com/goods-and-services-tax/     True   75.0
# 2  https://www.udemy.com/financial-modeling-for-b...     True   45.0
# 3  https://www.udemy.com/complete-excel-finance-c...     True   95.0
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True  200.0
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
udemy_course['year'] = udemy_course['published_date'].dt.year

# %%
udemy_course.groupby('year')['num_subscribers'].sum()
# Out:
# year
# 2011     119028
# 2012     555339
# 2013    1723438
# 2014    1930406
# 2015    3475324
# 2016    2966644
# 2017     991007
# Name: num_subscribers, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.lineplot(data = udemy_course,x='year', y='num_subscribers', hue = 'subject',ci=None)
plt.show()
# Out:
# C:\Users\Copy Center\AppData\Local\Temp\ipykernel_296\2947922124.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data = udemy_course,x='year', y='num_subscribers', hue = 'subject',ci=None)
